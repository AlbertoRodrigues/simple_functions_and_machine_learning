# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
dados=load_iris()

# %%
x=[]
for i in dados.target:
    if i==0:
        x.append("setosa")
    elif i==1:
        x.append("versicolor")
    else:
        x.append("virginica")
dados2=pd.DataFrame(dados.data,columns=dados.feature_names)
dados2["Resposta"]=x
dados2["Resposta Numerica"]=dados.target

# %%
dados2.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Resposta  Resposta Numerica
# 0   setosa                  0
# 1   setosa                  0
# 2   setosa                  0
# 3   setosa                  0
# 4   setosa                  0

# %%
dados2.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)  Resposta Numerica
# count        150.000000         150.000000
# mean           1.199333           1.000000
# std            0.762238           0.819232
# min            0.100000           0.000000
# 25%            0.300000           0.000000
# 50%            1.300000           1.000000
# 75%            1.800000           2.000000
# max            2.500000           2.000000

# %%
dados2.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# Resposta Numerica           0.782561         -0.426658           0.949035
#
#                    petal width (cm)  Resposta Numerica
# sepal length (cm)          0.817941           0.782561
# sepal width (cm)          -0.366126          -0.426658
# petal length (cm)          0.962865           0.949035
# petal width (cm)           1.000000           0.956547
# Resposta Numerica          0.956547           1.000000

# %%
dados2.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Resposta             0
# Resposta Numerica    0
# dtype: int64

# %%
dados2.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'Resposta', 'Resposta Numerica'],
#       dtype='object')

# %%
plt.hist(dados2['sepal length (cm)'],color="blue")
plt.xlabel("Tamanho da sépala")
plt.title("Histograma")
plt.show()

# %%
plt.scatter(range(len(dados2["sepal length (cm)"])) \
,dados2["sepal length (cm)"],c=dados2["Resposta Numerica"])
plt.show()

# %%
plt.scatter(dados2["sepal length (cm)"],dados2["petal length (cm)"]\
,c=dados2["Resposta Numerica"])
plt.xlabel("Tamanho da Sépala")
plt.ylabel("Tamanho da Pétala")
plt.title("Gráfico de dispersão")
plt.show()

# %%
pd.plotting.scatter_matrix(dados2[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', \
'petal width (cm)', 'Resposta']],figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B8399A42B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839EA3898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839EC5E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839C663C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B839C8E940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839CB5EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839CE7470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839D0EA20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B839D0EA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839D67518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839D8EA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839DC2048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B839DE85C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B839E10B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A0430F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A06A668>]],
#       dtype=object)

# %%
dados2.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A8C61D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A8E4780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A280B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A2AF128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A2D76A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B83A2FFC18>]],
#       dtype=object)
